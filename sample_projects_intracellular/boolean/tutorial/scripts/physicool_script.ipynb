# %%
# %matplotlib inline
from physicool.processing import get_cell_trajectories
from physicool.processing import get_cell_data
from physicool.plotting import plot_trajectories_3d, plot_trajectories_2d
from physicool import optimization as opt
from matplotlib import pyplot as plt

# %%
my_model = opt.PhysiCellBlackBox(project_name="project", project_config=" ./config/differentiation/PhysiCell_settings_2D_diff.xml")
my_model.run(number_of_replicates=2, keep_files=True)
# Out:
# Starting the replicates
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# /tmp/ipykernel_70342/1519665854.py in <module>
#       1 my_model = opt.PhysiCellBlackBox(project_name="project", project_config=" ./config/differentiation/PhysiCell_settings_2D_diff.xml")
# ----> 2 my_model.run(number_of_replicates=2, keep_files=True)
#
# ~/anaconda3/lib/python3.9/site-packages/physicool/optimization.py in run(self, params, number_of_replicates, keep_files)
#     145             if (number_of_replicates > 1) & keep_files:
#     146                 storage_folder = f"temp/replicate{i}"
# --> 147                 Path(storage_folder).mkdir()
#     148
#     149             log_status = f"running project with command {self.project_command}..."
#
# ~/anaconda3/lib/python3.9/pathlib.py in mkdir(self, mode, parents, exist_ok)
#    1321         """
#    1322         try:
# -> 1323             self._accessor.mkdir(self, mode)
#    1324         except FileNotFoundError:
#    1325             if not parents or self.parent == self:
#
# FileExistsError: [Errno 17] File exists: 'temp/replicate0'

# %%
trajectories = get_cell_trajectories("temp/replicate1/")
plot_trajectories_3d(trajectories)
plt.savefig("differentiation.png", dpi=300)
