# %%
import numpy as np
import seaborn as sns

import ginsim
import biolqm
import maboss
from itertools import combinations # for iterating over sets
import matplotlib.pyplot as plt # for modifying plots
import pandas as pd # for the visualization of lists of states
import pydot

import os

from tools import load_trajs, draw_graph_from_pandas, compute_circuits, compute_stg_counts

# %%
path = "./boolean_network/"

# %%
bnd_file = path + "sizek.bnd"
cfg_file = path + "sizek_sustained.cfg"

masim = maboss.load(bnd_file, cfg_file)

# %%
#Wild type

sim = masim.copy()

outputs = [ "Cdh1", "Cdc20"]

cyclins = ["CyclinA", "CyclinB", "CyclinE", "Casp3"]

sim.network.set_output(cyclins)

model = sim.run()

model.plot_piechart()
# Out:
# /home/marco/anaconda3/envs/MaBoSS_env/lib/python3.9/site-packages/maboss/figures.py:86: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   ax.pie(plot_line, labels=plotting_labels, radius=1.2,

# %%
model.plot_trajectory()

# %%
## Discrete time
WT_phenotypes_discrete = sim.copy()
WT_phenotypes_discrete.update_parameters(discrete_time=1, time_tick=1, max_time=150)

# %%
# %time res_discrete = WT_phenotypes_discrete.run()
# Out:
# CPU times: user 431 µs, sys: 4.59 ms, total: 5.02 ms
# Wall time: 274 ms

# %%
res_discrete.plot_node_trajectory()

# %%
res_discrete.plot_trajectory()

# %% [markdown]
# # Analysis of the model for PhysiBoSS with phenotypes output

# %%
bnd_file = path + "sizek_phenotypes.bnd"
cfg_file = path + "sizek_sustained_phenotypes.cfg"

sim_phenotypes = maboss.load(bnd_file, cfg_file)

# %%
WT_phenotypes = sim_phenotypes.copy()

WT_result = WT_phenotypes.run()

# %%
WT_result.plot_trajectory()

# %%
WT_result.plot_piechart()

# %%
# %time res = WT_phenotypes.run()
res.plot_node_trajectory()
# Out:
# CPU times: user 668 µs, sys: 6.92 ms, total: 7.58 ms
# Wall time: 3.49 s

# %%
## Discrete time
WT_phenotypes_discrete = WT_phenotypes.copy()
WT_phenotypes_discrete.update_parameters(discrete_time=1, time_tick=1, max_time=100)

cyclins = ["CyclinA", "CyclinB", "CyclinE", "CyclinD1"]

WT_phenotypes_discrete.network.set_output(cyclins)

# %%
# %time res_discrete = WT_phenotypes_discrete.run()
# Out:
# CPU times: user 3.06 ms, sys: 3.7 ms, total: 6.75 ms
# Wall time: 190 ms

# %%
res_discrete.plot_trajectory()

# %%
res_discrete.plot_node_trajectory()

# %%
res_discrete.plot_piechart()

# %%
outputs_phenotype = ["G0G1_exit", "G2M_exit", "S_exit"]
WT_phenotypes_discrete.network.set_output(outputs_phenotype)

# %time res_discrete = WT_phenotypes_discrete.run()
res_discrete.plot_node_trajectory()
# Out:
# CPU times: user 0 ns, sys: 6.87 ms, total: 6.87 ms
# Wall time: 187 ms

# %%
res_discrete.plot_trajectory()

# %%
WT_phenotypes_trajs = WT_phenotypes.copy()
WT_phenotypes_trajs.update_parameters(display_traj=1, thread_count=1)

# %%
# %time res_trajs = WT_phenotypes_trajs.run()
# Out:
# CPU times: user 4.45 ms, sys: 44.4 ms, total: 48.8 ms
# Wall time: 24.8 s

# %%
outputs = ["CyclinA", "CyclinB", "CyclinE", "CyclinD1"]
outputs_phenotype = ["G0G1_exit", "G2M_exit", "S_exit"]
trajs, all_states = load_trajs(res_trajs._path, outputs_phenotype, )
stg_counts, state_ids, ids_state = compute_stg_counts(trajs, all_states)

# %%
data = pd.DataFrame(
    data=stg_counts,
    index=state_ids.keys(), columns=state_ids.keys()
)
data
# Out:
#                                             <nil>  CyclinA  \
# <nil>                                         0.0    292.0
# CyclinA                                    2229.0      0.0
# CyclinA -- CyclinB                            0.0    536.0
# CyclinA -- CyclinB -- CyclinD1                0.0      0.0
# CyclinA -- CyclinB -- CyclinD1 -- CyclinE     0.0      0.0
# CyclinA -- CyclinB -- CyclinE                 0.0      0.0
# CyclinA -- CyclinD1                           0.0   3095.0
# CyclinA -- CyclinD1 -- CyclinE                0.0      0.0
# CyclinA -- CyclinE                            0.0    810.0
# CyclinB                                    2161.0      0.0
# CyclinB -- CyclinD1                           0.0      0.0
# CyclinB -- CyclinD1 -- CyclinE                0.0      0.0
# CyclinB -- CyclinE                            0.0      0.0
# CyclinD1                                   2827.0      0.0
# CyclinD1 -- CyclinE                           0.0      0.0
# CyclinE                                     275.0      0.0
#
#                                            CyclinA -- CyclinB  \
# <nil>                                                     0.0
# CyclinA                                                1770.0
# CyclinA -- CyclinB                                        0.0
# CyclinA -- CyclinB -- CyclinD1                         4299.0
# CyclinA -- CyclinB -- CyclinD1 -- CyclinE                 0.0
# CyclinA -- CyclinB -- CyclinE                           809.0
# CyclinA -- CyclinD1                                       0.0
# CyclinA -- CyclinD1 -- CyclinE                            0.0
# CyclinA -- CyclinE                                        0.0
# CyclinB                                                   7.0
# CyclinB -- CyclinD1                                       0.0
# CyclinB -- CyclinD1 -- CyclinE                            0.0
# CyclinB -- CyclinE                                        0.0
# CyclinD1                                                  0.0
# CyclinD1 -- CyclinE                                       0.0
# CyclinE                                                   0.0
#
#                                            CyclinA -- CyclinB -- CyclinD1  \
# <nil>                                                                 0.0
# CyclinA                                                               0.0
# CyclinA -- CyclinB                                                 3315.0
# CyclinA -- CyclinB -- CyclinD1                                        0.0
# CyclinA -- CyclinB -- CyclinD1 -- CyclinE                          3443.0
# CyclinA -- CyclinB -- CyclinE                                         0.0
# CyclinA -- CyclinD1                                                4481.0
# CyclinA -- CyclinD1 -- CyclinE                                        0.0
# CyclinA -- CyclinE                                                    0.0
# CyclinB                                                               0.0
# CyclinB -- CyclinD1                                                 109.0
# CyclinB -- CyclinD1 -- CyclinE                                        0.0
# CyclinB -- CyclinE                                                    0.0
# CyclinD1                                                              0.0
# CyclinD1 -- CyclinE                                                   0.0
# CyclinE                                                               0.0
#
#                                            CyclinA -- CyclinB -- CyclinD1 -- CyclinE  \
# <nil>                                                                            0.0
# CyclinA                                                                          0.0
# CyclinA -- CyclinB                                                               0.0
# CyclinA -- CyclinB -- CyclinD1                                                  19.0
# CyclinA -- CyclinB -- CyclinD1 -- CyclinE                                        0.0
# CyclinA -- CyclinB -- CyclinE                                                  104.0
# CyclinA -- CyclinD1                                                              0.0
# CyclinA -- CyclinD1 -- CyclinE                                                3929.0
# CyclinA -- CyclinE                                                               0.0
# CyclinB                                                                          0.0
# CyclinB -- CyclinD1                                                              0.0
# CyclinB -- CyclinD1 -- CyclinE                                                  21.0
# CyclinB -- CyclinE                                                               0.0
# CyclinD1                                                                         0.0
# CyclinD1 -- CyclinE                                                              0.0
# CyclinE                                                                          0.0
#
#                                            CyclinA -- CyclinB -- CyclinE  \
# <nil>                                                                0.0
# CyclinA                                                              0.0
# CyclinA -- CyclinB                                                   1.0
# CyclinA -- CyclinB -- CyclinD1                                       0.0
# CyclinA -- CyclinB -- CyclinD1 -- CyclinE                          525.0
# CyclinA -- CyclinB -- CyclinE                                        0.0
# CyclinA -- CyclinD1                                                  0.0
# CyclinA -- CyclinD1 -- CyclinE                                       0.0
# CyclinA -- CyclinE                                                 399.0
# CyclinB                                                              0.0
# CyclinB -- CyclinD1                                                  0.0
# CyclinB -- CyclinD1 -- CyclinE                                       0.0
# CyclinB -- CyclinE                                                   1.0
# CyclinD1                                                             0.0
# CyclinD1 -- CyclinE                                                  0.0
# CyclinE                                                              0.0
#
#                                            CyclinA -- CyclinD1  \
# <nil>                                                      0.0
# CyclinA                                                  720.0
# CyclinA -- CyclinB                                         0.0
# CyclinA -- CyclinB -- CyclinD1                          1171.0
# CyclinA -- CyclinB -- CyclinD1 -- CyclinE                  0.0
# CyclinA -- CyclinB -- CyclinE                              0.0
# CyclinA -- CyclinD1                                        0.0
# CyclinA -- CyclinD1 -- CyclinE                          6870.0
# CyclinA -- CyclinE                                         0.0
# CyclinB                                                    0.0
# CyclinB -- CyclinD1                                        0.0
# CyclinB -- CyclinD1 -- CyclinE                             0.0
# CyclinB -- CyclinE                                         0.0
# CyclinD1                                                2790.0
# CyclinD1 -- CyclinE                                        0.0
# CyclinE                                                    0.0
#
#                                            CyclinA -- CyclinD1 -- CyclinE  \
# <nil>                                                                 0.0
# CyclinA                                                               0.0
# CyclinA -- CyclinB                                                    0.0
# CyclinA -- CyclinB -- CyclinD1                                        0.0
# CyclinA -- CyclinB -- CyclinD1 -- CyclinE                             7.0
# CyclinA -- CyclinB -- CyclinE                                         0.0
# CyclinA -- CyclinD1                                                 191.0
# CyclinA -- CyclinD1 -- CyclinE                                        0.0
# CyclinA -- CyclinE                                                   51.0
# CyclinB                                                               0.0
# CyclinB -- CyclinD1                                                   0.0
# CyclinB -- CyclinD1 -- CyclinE                                        0.0
# CyclinB -- CyclinE                                                    0.0
# CyclinD1                                                              0.0
# CyclinD1 -- CyclinE                                               11613.0
# CyclinE                                                               0.0
#
#                                            CyclinA -- CyclinE  CyclinB  \
# <nil>                                                     0.0     67.0
# CyclinA                                                  11.0      0.0
# CyclinA -- CyclinB                                        0.0   3018.0
# CyclinA -- CyclinB -- CyclinD1                            0.0      0.0
# CyclinA -- CyclinB -- CyclinD1 -- CyclinE                 0.0      0.0
# CyclinA -- CyclinB -- CyclinE                             2.0      0.0
# CyclinA -- CyclinD1                                       0.0      0.0
# CyclinA -- CyclinD1 -- CyclinE                         1025.0      0.0
# CyclinA -- CyclinE                                        0.0      0.0
# CyclinB                                                   0.0      0.0
# CyclinB -- CyclinD1                                       0.0    809.0
# CyclinB -- CyclinD1 -- CyclinE                            0.0      0.0
# CyclinB -- CyclinE                                        0.0     17.0
# CyclinD1                                                  0.0      0.0
# CyclinD1 -- CyclinE                                       0.0      0.0
# CyclinE                                                 228.0      0.0
#
#                                            CyclinB -- CyclinD1  \
# <nil>                                                      0.0
# CyclinA                                                    0.0
# CyclinA -- CyclinB                                         0.0
# CyclinA -- CyclinB -- CyclinD1                          5836.0
# CyclinA -- CyclinB -- CyclinD1 -- CyclinE                  0.0
# CyclinA -- CyclinB -- CyclinE                              0.0
# CyclinA -- CyclinD1                                        0.0
# CyclinA -- CyclinD1 -- CyclinE                             0.0
# CyclinA -- CyclinE                                         0.0
# CyclinB                                                 1733.0
# CyclinB -- CyclinD1                                        0.0
# CyclinB -- CyclinD1 -- CyclinE                            95.0
# CyclinB -- CyclinE                                         0.0
# CyclinD1                                                 291.0
# CyclinD1 -- CyclinE                                        0.0
# CyclinE                                                    0.0
#
#                                            CyclinB -- CyclinD1 -- CyclinE  \
# <nil>                                                                 0.0
# CyclinA                                                               0.0
# CyclinA -- CyclinB                                                    0.0
# CyclinA -- CyclinB -- CyclinD1                                        0.0
# CyclinA -- CyclinB -- CyclinD1 -- CyclinE                            95.0
# CyclinA -- CyclinB -- CyclinE                                         0.0
# CyclinA -- CyclinD1                                                   0.0
# CyclinA -- CyclinD1 -- CyclinE                                        0.0
# CyclinA -- CyclinE                                                    0.0
# CyclinB                                                               0.0
# CyclinB -- CyclinD1                                                  44.0
# CyclinB -- CyclinD1 -- CyclinE                                        0.0
# CyclinB -- CyclinE                                                    1.0
# CyclinD1                                                              0.0
# CyclinD1 -- CyclinE                                                  26.0
# CyclinE                                                               0.0
#
#                                            CyclinB -- CyclinE  CyclinD1  \
# <nil>                                                     0.0    6324.0
# CyclinA                                                   0.0       0.0
# CyclinA -- CyclinB                                        0.0       0.0
# CyclinA -- CyclinB -- CyclinD1                            0.0       0.0
# CyclinA -- CyclinB -- CyclinD1 -- CyclinE                 0.0       0.0
# CyclinA -- CyclinB -- CyclinE                            10.0       0.0
# CyclinA -- CyclinD1                                       0.0    3766.0
# CyclinA -- CyclinD1 -- CyclinE                            0.0       0.0
# CyclinA -- CyclinE                                        0.0       0.0
# CyclinB                                                   3.0       0.0
# CyclinB -- CyclinD1                                       0.0    6970.0
# CyclinB -- CyclinD1 -- CyclinE                            6.0       0.0
# CyclinB -- CyclinE                                        0.0       0.0
# CyclinD1                                                  0.0       0.0
# CyclinD1 -- CyclinE                                       0.0    1534.0
# CyclinE                                                   1.0       0.0
#
#                                            CyclinD1 -- CyclinE  CyclinE
# <nil>                                                      0.0     24.0
# CyclinA                                                    0.0      0.0
# CyclinA -- CyclinB                                         0.0      0.0
# CyclinA -- CyclinB -- CyclinD1                             0.0      0.0
# CyclinA -- CyclinB -- CyclinD1 -- CyclinE                  0.0      0.0
# CyclinA -- CyclinB -- CyclinE                              0.0      0.0
# CyclinA -- CyclinD1                                        0.0      0.0
# CyclinA -- CyclinD1 -- CyclinE                            30.0      0.0
# CyclinA -- CyclinE                                         0.0      5.0
# CyclinB                                                    0.0      0.0
# CyclinB -- CyclinD1                                        0.0      0.0
# CyclinB -- CyclinD1 -- CyclinE                            44.0      0.0
# CyclinB -- CyclinE                                         0.0      1.0
# CyclinD1                                               13611.0      0.0
# CyclinD1 -- CyclinE                                        0.0    499.0
# CyclinE                                                   25.0      0.0

# %%
draw_graph_from_pandas(data)

# %%
probas = pd.DataFrame(
    data=np.divide(stg_counts,stg_counts.sum(axis=1)[:, np.newaxis]), 
    index=state_ids.keys(), columns=state_ids.keys()
)
probas
# Out:
#                           <nil>  G0G1_exit  G0G1_exit -- G2M_exit  \
# <nil>                  0.000000   0.601875               0.000000
# G0G1_exit              0.802180   0.000000               0.000000
# G0G1_exit -- G2M_exit  0.000000   0.970020               0.000000
# G0G1_exit -- S_exit    0.000000   0.295382               0.000000
# G2M_exit               0.697904   0.000000               0.290437
# G2M_exit -- S_exit     0.000000   0.000000               0.000000
# S_exit                 0.348802   0.000000               0.000000
#
#                        G0G1_exit -- S_exit  G2M_exit  G2M_exit -- S_exit  \
# <nil>                             0.000000  0.000000            0.000000
# G0G1_exit                         0.197820  0.000000            0.000000
# G0G1_exit -- G2M_exit             0.000000  0.029980            0.000000
# G0G1_exit -- S_exit               0.000000  0.000000            0.000000
# G2M_exit                          0.000000  0.000000            0.011659
# G2M_exit -- S_exit                0.000000  0.907557            0.000000
# S_exit                            0.097182  0.000000            0.554015
#
#                          S_exit
# <nil>                  0.398125
# G0G1_exit              0.000000
# G0G1_exit -- G2M_exit  0.000000
# G0G1_exit -- S_exit    0.704618
# G2M_exit               0.000000
# G2M_exit -- S_exit     0.092443
# S_exit                 0.000000

# %%
# %time paths_dict = compute_circuits(probas, ids_state, '<nil>', 0)
# Out:
# CPU times: user 4.52 ms, sys: 2.34 ms, total: 6.85 ms
# Wall time: 2.29 ms

# %%
for proba in sorted(paths_dict, reverse=True):
    #if proba > 0.01:
    print("%.2f : %s" % (proba, paths_dict[proba]))
# Out:
# 0.48 : ['<nil>', 'G0G1_exit']
# 0.14 : ['<nil>', 'S_exit', 'G2M_exit -- S_exit', 'G2M_exit']
# 0.14 : ['<nil>', 'S_exit']
# 0.05 : ['<nil>', 'S_exit', 'G2M_exit -- S_exit', 'G2M_exit', 'G0G1_exit -- G2M_exit', 'G0G1_exit']
# 0.03 : ['<nil>', 'G0G1_exit', 'G0G1_exit -- S_exit', 'S_exit', 'G2M_exit -- S_exit', 'G2M_exit']
# 0.03 : ['<nil>', 'G0G1_exit', 'G0G1_exit -- S_exit', 'S_exit']
# 0.01 : ['<nil>', 'S_exit', 'G0G1_exit -- S_exit', 'G0G1_exit']
